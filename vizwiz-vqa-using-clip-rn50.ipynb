# %% [markdown]
# # VizWiz-VQA using CLIP (RN50)

# %% [markdown]
# ## Installing Required Libraries

# %%
# !pip install -qq ftfy
# !pip install -qq Levenshtein
# !pip install -qq git+https://github.com/openai/CLIP.git
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 1.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.7/161.7 kB 4.2 MB/s eta 0:00:00a 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 43.0 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.9 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 102.8 MB/s eta 0:00:0000:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 79.3 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 39.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 8.1 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 30.7 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.0 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.7 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 91.0 MB/s eta 0:00:00:00:0100:01
#   Building wheel for clip (setup.py) ... done

# %% [markdown]
# ## Importing Required Libraries

# %%
# Importing OS for system operations, numpy and pandas for data manipulation
import os
import numpy as np 
import pandas as pd
import math

# Importing tqdm to track computation progress
from tqdm.notebook import tqdm
# Importing tabulate for printing formatted results table
from tabulate import tabulate

# For data visualization, we will use matplotlib
import matplotlib.pyplot as plt

# For data preprocessing, we will use Counter, Levenshtein distance, Python Image Library and OneHotEncoder
from collections import Counter
import Levenshtein as lev
from PIL import Image
from sklearn.preprocessing import OneHotEncoder

# For saving and loading the preprocessed data, we will use pickle
import pickle

# For Building the model, we will use PyTorch and its functions
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import clip
from torch.utils.data import Dataset, DataLoader

# For taking the image from the URL, we will use requests
import requests

# For evaluation, we will need sklearn.metrics.average_precision_score
from sklearn.metrics import average_precision_score

# Importing json for results formatting which will be uploaded for evaluation
import json

# %% [markdown]
# ## Configuring the Notebook

# %%
# Configuring the paths for the dataset
INPUT_PATH = '/kaggle/input/vizwiz-2023-edition'
ANNOTATIONS_PATH = INPUT_PATH + '/Annotations'
TRAIN_PATH = INPUT_PATH + '/train/train'
VALIDATION_PATH = INPUT_PATH + '/val/val'
TEST_PATH = INPUT_PATH + '/test/test'
ANNOTATIONS_TRAIN_PATH = ANNOTATIONS_PATH + '/train.json'
ANNOTATIONS_VAL_PATH = ANNOTATIONS_PATH + '/val.json'
ANNOTATIONS_TEST_PATH = ANNOTATIONS_PATH + '/test.json'
OUTPUT_PATH = '/kaggle/working/'
MODEL_NAME = "RN50x64" # This is the backbone of the CLIP model

# Using accelerated computing if available
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device: ", DEVICE)
# Out:
# Device:  cuda

# %% [markdown]
# ## Creating dataframes

# %%
def read_dataframe(path):
    """
    Reads the JSON file and returns a dataframe with the required columns (image, question, answers, answer_type, answerable)

    Parameters:
        path (str): Path to the JSON file

    Returns:
        df (pandas.DataFrame): Dataframe with the required columns
    """
    df = pd.read_json(path)
    df = df[['image', 'question', 'answers', 'answer_type', 'answerable']]
    return df

# %%
train_df = read_dataframe(ANNOTATIONS_TRAIN_PATH)
val_df = read_dataframe(ANNOTATIONS_VAL_PATH)
test_df = pd.read_json(ANNOTATIONS_TEST_PATH)

# %%
# num_df = train_df[train_df['answer_type'] == 'number'][:3]
# u_df = train_df[train_df['answer_type'] == 'unanswerable'][:1]
# train_df = pd.concat([train_df[:10], num_df, u_df], ignore_index=True)

# num_val_df = val_df[val_df['answer_type'] == 'number'][:1]
# yn_val_df = val_df[val_df['answer_type'] == 'yes/no'][:1]
# val_df = pd.concat([val_df[:5], num_val_df, yn_val_df], ignore_index=True)

# test_df = test_df[:2]

# %%
test_df.head()
# Out:
#                       image                                           question
# 0  VizWiz_test_00000000.jpg                What is this? And what color is it?
# 1  VizWiz_test_00000001.jpg                                      What is this?
# 2  VizWiz_test_00000002.jpg  Has this oven gotten up to four hundred fifty ...
# 3  VizWiz_test_00000003.jpg                                      What is this?
# 4  VizWiz_test_00000004.jpg                                      What is this?

# %% [markdown]
# ## Processing Images & Questions using CLIP model

# %% [markdown]
# Instead of lazy processing of images and questions embeddings and recomputing them over and over during forward passes in the model, we can preprocess them and save them in a file using Pickle. This will save us a lot of time when we want to train our model and decrease the time taken by one epoch drastically.

# %%
def process_images(dataframe, image_path, clip_model, preprocessor, device):
    """
    Processes the images in the dataframe and returns the image features

    Parameters:
        dataframe (pandas.DataFrame): Dataframe containing the images
        image_path (str): Path to the input images
        clip_model (clip.model.CLIP): CLIP model
        preprocessor (clip.model.Preprocess): Preprocessor for the CLIP model
        device (torch.device): Device to be used for processing
    
    Returns:
        images (list): List of image features
    """
    images = []
    for _, row in tqdm(dataframe.iterrows(), total=len(dataframe)):
        full_path = image_path + "/" + row['image']
        image = Image.open(full_path)
        image = preprocessor(image).unsqueeze(0).to(device)
        image_features = clip_model.encode_image(image).squeeze().detach() # torch.Size([1024])
        images.append(image_features)
    return images

def process_questions(dataframe, clip_model, device):
    """
    Processes the questions in the dataframe and returns the question features

    Parameters:
        dataframe (pandas.DataFrame): Dataframe containing the questions
        clip_model (clip.model.CLIP): CLIP model
        device (torch.device): Device to be used for processing

    Returns:
        questions (list): List of question features
    """
    questions = []
    for _, row in tqdm(dataframe.iterrows(), total=len(dataframe)):
        question = row['question']
        question =  clip.tokenize(question).to(device)
        text_features = clip_model.encode_text(question).float().squeeze().detach() # torch.Size([1024])
        questions.append(text_features)
    return questions

# %%
clip.available_models()
# Out:
# ['RN50',
#  'RN101',
#  'RN50x4',
#  'RN50x16',
#  'RN50x64',
#  'ViT-B/32',
#  'ViT-B/16',
#  'ViT-L/14',
#  'ViT-L/14@336px']

# %%
clip_model, preprocessor = clip.load(MODEL_NAME, device = DEVICE)
clip_model.eval().requires_grad_(False);
# Out:
# 100%|█████████████████████████████████████| 1.26G/1.26G [02:35<00:00, 8.69MiB/s]

# %% [markdown]
# ### Feature Extraction Of Image-Question pairs & Save To File

# %%
training_images = process_images(train_df, TRAIN_PATH, clip_model, preprocessor, DEVICE)
training_questions = process_questions(train_df, clip_model, DEVICE)
with open(OUTPUT_PATH + 'training_images.pkl', 'wb') as f:
    pickle.dump(training_images, f)
with open(OUTPUT_PATH + 'training_questions.pkl', 'wb') as f:
    pickle.dump(training_questions, f)

validation_images = process_images(val_df, VALIDATION_PATH, clip_model, preprocessor, DEVICE)
validation_questions = process_questions(val_df, clip_model, DEVICE)
with open(OUTPUT_PATH + 'validation_images.pkl', 'wb') as f:
    pickle.dump(validation_images, f)
with open(OUTPUT_PATH + 'validation_questions.pkl', 'wb') as f:
    pickle.dump(validation_questions, f)
# Out:
#   0%|          | 0/20523 [00:00<?, ?it/s]
#   0%|          | 0/20523 [00:00<?, ?it/s]
#   0%|          | 0/4319 [00:00<?, ?it/s]
#   0%|          | 0/4319 [00:00<?, ?it/s]

# %%
test_images = process_images(test_df, TEST_PATH, clip_model, preprocessor, DEVICE)
test_questions = process_questions(test_df, clip_model, DEVICE)
with open(OUTPUT_PATH + 'test_images.pkl', 'wb') as f:
    pickle.dump(test_images, f)
with open(OUTPUT_PATH + 'test_questions.pkl', 'wb') as f:
    pickle.dump(test_questions, f)
# Out:
#   0%|          | 0/8000 [00:00<?, ?it/s]
#   0%|          | 0/8000 [00:00<?, ?it/s]

# %% [markdown]
# ### Loading Processed Embeddings

# %%
with open(OUTPUT_PATH + 'training_images.pkl', 'rb') as f:
    training_images = pickle.load(f)
with open(OUTPUT_PATH + 'training_questions.pkl', 'rb') as f:
    training_questions = pickle.load(f)

with open(OUTPUT_PATH + 'validation_images.pkl', 'rb') as f:
    validation_images = pickle.load(f)
with open(OUTPUT_PATH + 'validation_questions.pkl', 'rb') as f:
    validation_questions = pickle.load(f)

with open(OUTPUT_PATH + 'test_images.pkl', 'rb') as f:
    test_images = pickle.load(f)
with open(OUTPUT_PATH + 'test_questions.pkl', 'rb') as f:
    test_questions = pickle.load(f)

# %%
len(training_images), len(validation_images), len(test_images)
# Out:
# (20523, 4319, 8000)

# %%
training_images[0].shape, training_questions[0].shape
# Out:
# (torch.Size([1024]), torch.Size([1024]))

# %% [markdown]
# ## Creating the Answer Vocabulary

# %%
def get_global_answer_vocab(train_df, val_df):
    """
    Accumulates all unique answers in the training and validation set

    Parameters:
        train_df (pandas.DataFrame): Dataframe containing training samples
        val_df (pandas.DataFrame): Dataframe containing validation samples
    
    Returns:
        global_answer_vocab (Counter): Counter containing all unique answers and their freq
    """
    joint_df = pd.concat([train_df, val_df], ignore_index=True)
    
    # Total counter for all answers before filtering, used in Tie Breaking when building the answer vocabulary
    global_answer_vocab = Counter()
    for row in joint_df['answers']:
        for answer_map in row:
            global_answer_vocab.update([answer_map['answer']])

    return global_answer_vocab

def select_candidate_answers(dataframe, global_answer_vocab):
    """
    Selects one candidate answer for each row in the dataframe by the following policy:
    - for each question we have 10 answers, we choose the most frequent answer as the answer for this question
    - if there is a tie, we choose the most common one in the global_answer_vocab
    - if there is a tie, the pairwise Levenshtein distance is used to find the answer that is most representative to all others.

    Parameters:
        dataframe (pandas.DataFrame): Dataframe containing samples
        global_answer_vocab (Counter): Counter containing all unique answers and their freq
    
    Returns:
        final_dataframe (pandas.DataFrame): Dataframe containing refined samples
    """
    # Copying the original dataframe which will be manipulated
    final_dataframe = dataframe.copy()
    final_dataframe.drop(columns=['answers'], inplace=True)
    
    # Adding extra column named 'answer'
    final_dataframe['answer'] = None
    
    for index, row in dataframe.iterrows():
        intermediate_counter = Counter()
        for answer_map in row['answers']:
            answer = answer_map['answer']
            intermediate_counter.update([answer])
                
        # let's see the top elements in the intermediate_counter to check if there is a tie
        top_freq = max(intermediate_counter.values())
        top_elements = [(k, v) for k, v in intermediate_counter.items() if v == top_freq]
    
        if len(top_elements) == 1:
            final_dataframe.at[index, 'answer'] = top_elements[0][0]
            continue
                    
        # Else let's see who is the most common answer in the whole dataset
        top_elements_in_dataset = []
        top_freq = -1
        for k, v in top_elements:
            if global_answer_vocab[k] > top_freq:
                top_freq = global_answer_vocab[k]
                top_elements_in_dataset.clear()
                top_elements_in_dataset.append(k)
            elif global_answer_vocab[k] == top_freq:
                top_elements_in_dataset.append(k)
        
        if len(top_elements_in_dataset) == 1:
            final_dataframe.at[index, 'answer'] = top_elements_in_dataset[0]
            continue
                    
        # Else let's get the minimum levenshtein distance between the answers in top_elements_in_dataset
        current_min = np.inf
        current_answer = None
        for answer in top_elements_in_dataset:
            total_distance = 0
            for answer2 in top_elements_in_dataset:
                if answer != answer2:
                    lev_distance = lev.distance(answer, answer2)
                    total_distance += lev_distance
            if total_distance < current_min:
                current_min = total_distance
                current_answer = answer
        final_dataframe.at[index, 'answer'] = current_answer

    return final_dataframe

def get_answer_encoder(train_df, val_df):
    """
    Obtains the model answer vocab, number of classes and fits the one hot encoder

    Parameters:
        train_df (pandas.DataFrame): Dataframe containing refined training samples
        val_df (pandas.DataFrame): Dataframe containing refined validation samples
    
    Returns:
        answer_encoder (OneHotEncoder): One Hot Encoder for the answers
    """
    joint_df = pd.concat([train_df, val_df], ignore_index=True)
    answer_encoder = OneHotEncoder(handle_unknown='ignore')
    answer_encoder.fit(joint_df[['answer']])
    return answer_encoder

def get_answer_type_encoder(train_df):
    """
    Obtains the model answer vocab, number of classes and fits the one hot encoder

    Parameters:
        train_df (pandas.DataFrame): Dataframe containing training samples
    Returns:
        answer_type_encoder (OneHotEncoder): One Hot Encoder for the answer types
    """
    answer_type_encoder = OneHotEncoder(handle_unknown='ignore')
    answer_type_encoder.fit(train_df[['answer_type']])
    return answer_type_encoder

# %%
global_answer_vocab = get_global_answer_vocab(train_df, val_df)
len(global_answer_vocab)
# Out:
# 48727

# %%
train_df_final = select_candidate_answers(train_df, global_answer_vocab)
val_df_final = select_candidate_answers(val_df, global_answer_vocab)

# %%
answer_encoder = get_answer_encoder(train_df_final, val_df_final)
answer_type_encoder = get_answer_type_encoder(train_df)

# %%
ANSWER_CATEGORIES = answer_encoder.categories_[0].tolist()

# %%
NUM_CLASSES = len(answer_encoder.categories_[0].tolist())
NUM_CLASSES
# Out:
# 5545

# %%
ANSWER_CATEGORIES
# Out:
# ['$1.05',
#  '$10 gift card',
#  '$10 off',
#  '$100.81',
#  '$125',
#  '$150 gift card',
#  '$16.99',
#  '$25 starbucks gift card',
#  '$5 avocado bacon tostada combo',
#  '$50 preferred guest card',
#  '$7.98',
#  '0',
#  '0 7818 0354 3',
#  '0.0 5.0 233',
#  '0.125',
#  '0.5 2:02',
#  '00 3.10 539',
#  '01 05 13',
#  '01 07 12',
#  '01 15 13',
#  '021 08454',
#  '02577039',
#  '02610518',
#  '02616272',
#  '04',
#  '04 35 36 42 50 01 02',
#  '04669861010001',
#  '05 18',
#  '053 435 31 81',
#  '05n5801 veritas set up blocks',
#  '07 11 2013',
#  '0845 7 48 49 50',
#  '0:17',
#  '0:37',
#  '1',
#  '1 2 cup',
#  '1 3',
#  '1 3 cup',
#  '1 877 328 9677',
#  '1 dollar',
#  '1 dollar bill',
#  '1 dollar singapore',
#  '1 foot',
#  '1 half cups water 3 tablespoons butter',
#  '1 hour 25 minutes',
#  '1 inch',
#  '1 line',
#  '1 minute 30 seconds',
#  '1 on left',
#  '1% lowfat milk',
#  '1.25',
#  '1.29',
#  '1.29 1.99',
#  '1.5',
#  '10',
#  '10 07 12',
#  '10 21 15',
#  '10 apr 13',
#  '10 dollar bill',
#  '10 euros',
#  '10 mg',
#  '10 pound note',
#  '10 pounds',
#  '100',
#  '100 degrees',
#  '100 dollar bill',
#  '100 hong kong dollars',
#  '100 pounds',
#  '1000',
#  '10000',
#  '101',
#  '101 dalmatians',
#  '1020mg',
#  '103',
#  '103.7',
#  '105.2',
#  '105.8',
#  '106',
#  '106.4',
#  '106.8',
#  '107',
#  '108 68',
#  '10:12',
#  '10:36',
#  '10:37',
#  '10:43',
#  '10:46',
#  '11 26 2013',
#  '111 72',
#  '111 87',
#  '115 cm',
#  '116 over 65',
#  '119 82',
#  '11:03',
#  '11:26',
#  '11:48',
#  '12 15 minutes',
#  '12 2013',
#  '12 hour slow cooker recipes',
#  '12.79',
#  '12.99',
#  '120',
#  '121',
#  '121.5',
#  '122.2',
#  '123.8',
#  '125.58',
#  '1284353636',
#  '12999.01',
#  '12:04',
#  '12:10',
#  '12:12',
#  '12:15',
#  '12:28',
#  '12:39',
#  '13',
#  '131',
#  '135.276',
#  '14 2013',
#  '14 classic easter songs',
#  '14 percent complete',
#  '140',
#  '145',
#  '147',
#  '148 75',
#  '1482',
#  '149.00',
#  '15',
#  '15 18 minutes',
#  '150',
#  '1503c',
#  '16',
#  '16 1 2',
#  '1621',
#  '171',
#  '18',
#  '18.5',
#  '180',
#  '18431',
#  '1865',
#  '18:37',
#  '195',
#  '1:05',
#  '1:09',
#  '1:11',
#  '1:27',
#  '1:37',
#  '1:40',
#  '1:43',
#  '1:45',
#  '1:48',
#  '2',
#  '2 birds',
#  '2 dollars',
#  '2 minutes',
#  '2 spades',
#  '2 spicy bean burgers',
#  '2 wands',
#  '2 weeks',
#  '2%',
#  '2.0 0.0',
#  '2.26.00',
#  '20',
#  '20 canadian dollars',
#  '20 cent',
#  '20 dollar bill',
#  '20 dollars',
#  '20 euro',
#  '200',
#  '2000',
#  '2010 iowa state football',
#  '2012',
#  '2012 eoc',
#  '2095',
#  '2103 sale k',
#  '216',
#  '21820',
#  '23 26 29 33 44 47 03 11 14 31 41 49',
#  '230',
#  '23442',
#  '23:24',
#  '23jl6pje',
#  '24',
#  '242',
#  '25',
#  '25.00',
#  '250',
#  '25389186',
#  '25mg',
#  '26',
#  '26.702',
#  '271.75',
#  '275',
#  '278900',
#  '28',
#  '28 years',
#  '28.8',
#  '2834',
#  '2854.562',
#  '287',
#  '29077008765328',
#  '2:00',
#  '2:02',
#  '2:03 timex',
#  '2:08',
#  '2:15',
#  '2:20',
#  '2:53',
#  '2rm5',
#  '3',
#  '3 cheese chicken quesadilla',
#  '3 cheese tortellini',
#  '3 degrees',
#  '3 inches',
#  '3 minutes',
#  '3 petrus',
#  '3 trophies',
#  '3.00',
#  '3.25',
#  '3.28',
#  '3.29',
#  '3.48',
#  '3.77',
#  '3.98',
#  '30',
#  '30 grams',
#  '300',
#  '301',
#  '30362',
#  '31 right side up',
#  '31.45 34.52',
#  '32 bit',
#  '3233 4347',
#  '325',
#  '33',
#  '330 upside down',
#  '335',
#  '34821',
#  '35',
#  '35.05',
#  '350',
#  '351 352 353 354 355',
#  '36.38',
#  '360',
#  '365 sour cream onion',
#  '37.84',
#  '375',
#  '37978',
#  '38',
#  '38.5',
#  '385',
#  '38i9rg48',
#  '39 clues',
#  '390mg',
#  '393',
#  '3:06',
#  '3:10',
#  '3:18',
#  '3:24',
#  '3:30',
#  '3:40',
#  '3:42',
#  '3:46',
#  '3d glasses',
#  '3d paint',
#  '3mcy8jl5',
#  '4',
#  '4 cheese',
#  '4 deuces',
#  '4 gb',
#  '4 shelves',
#  '4 white fish portions',
#  '4.16',
#  '4.19',
#  '4.22',
#  '4.31',
#  '4.54',
#  '4.57',
#  '4.63',
#  '4.65',
#  '4.75',
#  '4.89',
#  '4.96',
#  '4.97',
#  '40',
#  '400',
#  '409',
#  '409 all purpose cleaner',
#  '409 cleaner',
#  '410',
#  '41950',
#  '425',
#  '44.5',
#  '440',
#  '45% complete',
#  '450',
#  '452940',
#  '460',
#  '47',
#  '472 dahwit',
#  '475',
#  '48 clear pockets accessory organizer',
#  '4:23',
#  '4:35',
#  '4nxen',
#  '4t 5t',
#  '4tm9',
#  '4ycjfw8l',
#  '5',
#  '5 blue',
#  '5 dollar bill',
#  '5 dollars',
#  '5 euro',
#  '5 pounds',
#  '5.01',
#  '5.99',
#  '50',
#  '50 euro',
#  '50 pounds',
#  '50.00',
#  '500',
#  '500 sulfate',
#  '50000',
#  '5229',
#  '53',
#  '53716',
#  '55195',
#  '56',
#  '58',
#  '5803',
#  '59',
#  '59%',
#  '5:18',
#  '5:26',
#  '5:47 monday may 28',
#  '5:48 pm',
#  '5:59',
#  '5npj',
#  '5th season',
#  '6',
#  '6 cheese tortellini',
#  '6 wands right side up',
#  '6182714091',
#  '62.31',
#  '62410 62375',
#  '633',
#  '640mg',
#  '6466652864',
#  '65',
#  '662 780',
#  '67',
#  '68',
#  '69',
#  '6:55',
#  '6bfebr',
#  '6i5v',
#  '6ju7jc5e',
#  '7 brides for 7 brothers',
#  '7 layer burrito',
#  '7 minutes',
#  '7 professional',
#  '7.99',
#  '70',
#  '700mg',
#  '71',
#  '72',
#  '7259 7694',
#  '73',
#  '73.5',
#  '74',
#  '74.5',
#  '741',
#  '75',
#  '75 degrees',
#  '76',
#  '764666103016',
#  '77',
#  '77 76',
#  '78',
#  '78 1',
#  '78 degrees',
#  '788741',
#  '79',
#  '799852896',
#  '7:44',
#  '7ycjfw8l',
#  '8',
#  '8 clubs',
#  '8 minutes',
#  '80',
#  '80 cents',
#  '800 631 9554',
#  '800 643 2112 siriusxmcom',
#  '805',
#  '81',
#  '819',
#  '84',
#  '84pn',
#  '87.5',
#  '876512',
#  '88% complete',
#  '89',
#  '8:43',
#  '9',
#  '9 1 2',
#  '9 minutes',
#  '9 upside down',
#  '9 wands upside down',
#  '90',
#  '90f',
#  '92.67',
#  '94',
#  '9674',
#  '97 69',
#  '978 0 13 265811 9',
#  '9780132658119',
#  '97zh',
#  '98% fat free',
#  '99 cents',
#  '99.9 fm',
#  '9:33',
#  '9:39',
#  '9:40',
#  'a&w root beer',
#  'a1429',
#  'aaa',
#  'aarp',
#  'abba',
#  'abraham lincoln vampire hunter',
#  'acai deep conditioning masque',
#  'accordian',
#  'acd8d7',
#  'acetaminophen',
#  'acidophilus',
#  'acoustic',
#  'acquiring signal',
#  'act ii',
#  'action figure',
#  'ad',
#  'addison antique',
#  'adison taylor women',
#  'adult diapers',
#  'advance',
#  'advanced',
#  'advanced boot options',
#  'advanced creme rinse',
#  'advertisement',
#  'advil',
#  'advil pm',
#  'aeropostale',
#  'after shave',
#  'afterwards',
#  'agave',
#  'air conditioner',
#  'air conditioning',
#  'air freshener',
#  'air vent',
#  'airplane',
#  'airport extreme',
#  'ajax amsterdam',
#  'ajax dish soap',
#  'alabama crimson tide',
#  'aladdin natural eatery',
#  'alarm clock',
#  'alarm system',
#  'alcohol',
#  'aleve',
#  'alfalfa',
#  'alfredo',
#  'alfredo pasta sides',
#  'alfredo sauce',
#  'algidol',
#  'all bran yogurt bites',
#  'all dark',
#  'all day allergy',
#  'all day relief',
#  'all kids',
#  'all purpose',
#  'all that jazz',
#  'allergy medication',
#  'allergy medicine',
#  'allergy relief',
#  'allstate youre in good hands',
#  'almond',
#  'almond butter',
#  'almond crunch',
#  'almond flour',
#  'almond milk',
#  'almonds',
#  'aloe green tea',
#  'aloe vera gel',
#  'alpha bits',
#  'already booted',
#  'altoids',
#  'aluminum',
#  'aluminum foil',
#  'alumni',
#  'always',
#  'amanda',
#  'amber ale',
#  'american cancer society',
#  'american flag',
#  'american legion auxiliary',
#  'american spirit',
#  'amfc',
#  'amigo enhanced vision',
#  'amigos golden teashops',
#  'ammonia',
#  'amys',
#  'anchor',
#  'andes mints',
#  'andes peppermint crunch',
#  'anew eye treatment',
#  'angel',
#  'angry birds',
#  'animal crackers',
#  'animal unleashed',
#  'announcements',
#  'another photo',
#  'ant killer',
#  'ant roach killer',
#  'anti diarrheal',
#  'anti itch lotion',
#  'antibacterial counter spray',
#  'antibiotic ointment',
#  'any all above',
#  'app updates',
#  'appetizers',
#  'apple',
#  'apple cider vinegar',
#  'apple cinnamon',
#  'apple computer',
#  'apple crisps',
#  'apple juice',
#  'apple laptop',
#  'apple logo',
#  'apple pie',
#  'apple pie custard',
#  'apple pie spice',
#  'apple product',
#  'apple slices',
#  'apple strudel',
#  'apple tv update',
#  'apples',
#  'apples cinnamon',
#  'apples oranges kiwi',
#  'application study',
#  'approved for mast',
#  'apricot chicken rice',
#  'apsides',
#  'apsp',
#  'aqua',
#  'aquafina',
#  'aquafina water',
#  'aquarium',
#  'aramis cologne',
#  'arawak',
#  'arbor mist chardonnay peach',
#  'arizona',
#  'arm',
#  'arm hammer',
#  'armitron',
#  'army 2',
#  'artichoke bottoms',
#  'artichoke capsules',
#  'artichoke hearts',
#  'artisan',
#  'aruba coconut',
#  'ash tray',
#  'ashers',
#  'ashtray',
#  'ask doctor',
#  'aspall cider',
#  'asparagus spears',
#  'aspire',
#  'assorted',
#  'at desk',
#  'at podcasts twitter wha',
#  'at&t',
#  'attlyoc prisoner',
#  'au gratin',
#  'audio driver',
#  'auf die lange kommt es',
#  'aug 13 2012',
#  'aug 29',
#  'august',
#  'august 13 2012',
#  'august 14 2013',
#  'austin powers spy who shagged me',
#  'australia post',
#  'australian beef',
#  'australian lamb',
#  'authentic thai cuisine',
#  'automatic door stop',
#  'avatar',
#  'aveeno',
#  'aveeno daily moisturizing lotion',
#  'awake',
#  'awesome orange',
#  'axe',
#  'axe dry',
#  'aynt',
#  'azo standard maximum strength',
#  'b',
#  'baboon',
#  'baby blues mood remedy',
#  'baby cereal',
#  'baby food',
#  'baby formula',
#  'baby grand',
#  'baby oil',
#  'baby powder',
#  'baby rattle',
#  'baby shampoo',
#  'baby walker',
#  'baby wipes',
#  'bacardi',
#  'back',
#  'back head',
#  'back next',
#  'backpack',
#  'backseat car',
#  'backstage pass',
#  'backyard',
#  'backyard brawling',
#  'bacon',
#  'bacon bits',
#  'bactroban',
#  'bad',
#  'bag',
#  'bag balm',
#  'bag candy',
#  'bag chips',
#  'bags',
#  'baked beans',
#  'baked beans sausages',
#  'baked chicken',
#  'baked chicken mushroom sauce',
#  'baked mozzarella bites',
#  'baked potato cheddar bacon bits',
#  'baked turkey',
#  'bakery',
#  'bakery cafe',
#  'bakewell tart',
#  'baking mix for pork',
#  'baking spice',
#  'balance rewards',
#  'ball',
#  'ballast porter',
#  'ballatore',
#  'balls sanded',
#  'balsamic garlic chicken',
#  'bamboo shoots',
#  'banana',
#  'banana bread mix',
#  'banana chips',
#  'banana cream pie',
#  'banana nut',
#  'bananas',
#  'bandages',
#  'bar',
#  'bar b que restaurant',
#  'bar code',
#  'bar mitzvah',
#  'barack obama',
#  'barbacoa',
#  'barbecue',
#  'barbecue sauce',
#  'barbeque',
#  'barbie',
#  'barcode',
#  'barn fence',
#  'barnes noble gift card',
#  'bars',
#  'baseball',
#  'baseball card bob gibson',
#  'baseball nao',
#  'baseball stadium',
#  'basil',
#  'basil leaves',
#  'basil parmesan chicken',
#  'basketball',
#  'basketball hoop',
#  'bat',
#  'bath body works',
#  'bath gel',
#  'bath salts',
#  'bath shower gel',
#  'bathroom',
#  'bathroom cleaner',
#  'batteries',
#  'battery',
#  'battery low',
#  'bborax',
#  'bbq',
#  'bbq sauce',
#  'bbq tapioca chips',
#  'bd',
#  'be enchanted lotion',
#  'beach',
#  'bead',
#  'beagle',
#  'bean bacon',
#  'bean extract',
#  'beans',
#  'beans wieners',
#  'bear',
#  'beats by dr dre',
#  'beavis',
#  'because winn dixie',
#  'becks',
#  'bed',
#  'bed bath beyond',
#  'bed head',
#  'bed head control freak',
#  'bedroom',
#  'bee',
#  'beef',
#  'beef bean green chili',
#  'beef bouillon cubes',
#  'beef broccoli',
#  'beef broth',
#  'beef burgers',
#  'beef chuck steak',
#  'beef dinner',
#  'beef filled yorkshire pudding',
#  'beef goulash',
#  'beef gravy',
#  'beef jerky',
#  'beef meatballs',
#  'beef noodle soup',
#  'beef peppers',
#  'beef pot roast',
#  'beef ramen noodles',
#  'beef ravioli',
#  'beef shepherds pie',
#  'beef soup',
#  'beef steak mince',
#  'beef stew',
#  'beef stock',
#  'beef striploin',
#  'beef strips',
#  'beef stroganoff',
#  'beef tips',
#  'beefaroni',
#  'beer',
#  'beer bottle caps',
#  'beer bread mix',
#  'beer can',
#  'beer orange',
#  'beet',
#  'beetle',
#  'beets',
#  'beige',
#  'beige basket flowers',
#  'belkin',
#  'bell',
#  'bellorto',
#  'belly button',
#  'beloka',
#  'beloved',
#  'ben new',
#  'benadryl',
#  'benadryll',
#  'bench',
#  'bengay',
#  'bentley university',
#  'berry',
#  'berry blue',
#  'best buy',
#  'best johnny carson friends',
#  'beta',
#  'better',
#  'better homes gardens',
#  'better than bouillon',
#  'betty boop',
#  'beurre disigny',
#  'beverage',
#  'beverage dispenser',
#  'bible',
#  'big easy bold',
#  'big nut bar',
#  'big print address book',
#  'big toe',
#  'bill baileys remarkable guide to orchestra',
#  'billie holiday',
#  'binder clip',
#  'binoculars',
#  'bio oil',
#  'biotin',
#  'bird',
#  'bird cage',
#  'birds on branch',
#  'birthday',
#  'birthday card',
#  'biscuit baking mix',
#  'biscuits',
#  'bistro salad',
#  'black',
#  'black beans',
#  'black blue',
#  'black blue brown red',
#  'black brew',
#  'black brown',
#  'black car',
#  'black cherry',
#  'black dog',
#  'black dyna sys',
#  'black flashlight',
#  'black gold',
#  'black green',
#  'black green white',
#  'black grey',
#  'black lab',
#  'black little devil',
#  'black mountain blend',
#  'black multicultural academic affairs',
#  'black no',
#  'black olives',
#  'black onyx',
#  'black orange',
#  'black pants',
#  'black pepper',
#  'black pepper cracked',
#  'black pink',
#  'black plaid',
#  'black red',
#  'black red stripe',
#  'black red yes',
#  'black ruby',
#  'black silk',
#  'black silver',
#  'black stash premium',
#  'black tan',
#  'black tea',
#  'black tiger',
#  'black white',
#  'black white laying down',
#  'black white plaid',
#  'black white polka dots stripes',
#  'black white red',
#  'black yellow red blue',
#  'blackberry',
#  'blank',
#  'blank page',
#  'blanket',
#  'bleu classic',
#  'blind user support group',
#  'blindfold',
#  'blistex',
#  'blonde',
#  'bloodstone papers',
#  'blue',
#  'blue black',
#  'blue black red',
#  'blue black white',
#  'blue brown',
#  'blue buffalo',
#  'blue corn tortilla chips',
#  'blue cross blue shield',
#  'blue electric razor',
#  'blue electric shaver',
#  'blue fin',
#  'blue fish',
#  'blue flowers',
#  'blue green',
#  'blue green red',
#  'blue green red yellow',
#  'blue grey',
#  'blue lighter',
#  'blue lines',
#  'blue marvel',
#  'blue monkeys',
#  'blue moon',
#  'blue moose',
#  'blue orange white',
#  'blue pink',
#  'blue plaid',
#  'blue purple white orange',
#  'blue red',
#  'blue red yellow',
#  'blue screen',
#  'blue shirt white button',
#  'blue shirt yellow basketball',
#  'blue shorts',
#  'blue silver',
#  'blue white',
#  'blue white black',
#  'blue white checkered',
#  'blue white stripes',
#  'blue yellow',
#  'blueberry',
#  'blueberry brown sugar',
#  'blueberry lowfat yogurt',
#  'blueberry muffin mix',
#  'blueberry muffins',
#  'blueberry nut',
#  'blueberry peach',
#  'blueberry quick bread mix',
#  'bluegrass',
#  'bluetooth headset',
#  'blurry',
#  'boat',
#  'bob marley',
#  'bob wills',
#  'boca',
#  'body',
#  'body gel',
#  'body lotion',
#  'body spray',
#  'body wash',
#  'body wash conditioner',
#  'bombmaker',
#  'bombshell',
#  'bone',
#  'bone in lamb leg steaks',
#  'boneless beef short ribs',
#  'boneless pork roast',
#  'book',
#  'book shelf',
#  'bookcase',
#  'bookends',
#  'books',
#  'books photos speaker',
#  'boots',
#  'bop',
#  'borax',
#  'borsch',
#  'boscovs',
#  'bose',
#  'boska',
#  'boston',
#  'boston baked beans',
#  'boston market beef steak noodle',
#  'both',
#  'bottle',
#  'bottle cap',
#  'bottle caps',
#  'bottle water',
#  'bottled water',
#  'bottom',
#  'bottom card',
#  'bottom shoe',
#  'bowers wilkins',
#  'bowl',
#  'bowl noodles',
#  'bowser',
#  'box',
#  'box teabags',
#  'box tissues',
#  'boxcar children',
#  'boxer mix',
#  'boxer scottie',
#  'boy',
#  'boyds fine tea',
#  'bra on table',
#  'bracelet',
#  'brad dutz',
#  'braille',
#  'braille machine',
#  'braille note pk',
#  'braillele',
#  'braillenote',
#  'braised beef portobello tortellini',
#  'braised chicken almonds',
#  'brat kartoffeln',
#  'brazil santos',
#  'bread',
#  'bread crumbs',
#  'bread maker',
#  'breaded irish chicken goujons',
#  'breakfast',
#  'breakfast blend',
#  'breakfast blend decaf',
#  'breakfast bowl',
#  'breakfast in bed',
#  'breakfast sandwich',
#  'breakfast specials',
#  'breast',
#  'breath mints',
#  'breeder blend',
#  'breeders blend',
#  'brides maids',
#  'bridey 2003 2013',
#  'briefcase',
#  'bright',
#  'brillo pads',
#  'britney spears video',
#  'broccoli',
#  'broccoli au gratin',
#  'broccoli cheddar soup',
#  'broccoli cheese potato',
#  'broccoli florets',
#  'brochure',
#  'broil',
#  'brook benton',
#  'broth',
#  'brown',
#  'brown black',
#  'brown gravy',
#  ...]

# %% [markdown]
# ## Creating Dataset Class

# %%
class VizWizDataset(Dataset):
    def __init__(self, dataframe, dataframe_mlt, images_features, questions_features, answer_type_onehotencoder, answer_onehotencoder):
        
        super(VizWizDataset, self).__init__()

        # Saving image & question embeddings
        self.images_features = images_features
        self.questions_features = questions_features
        self.answerable = dataframe['answerable'].to_numpy()

        # Saving the dataframe
        self.dataframe = dataframe
        self.dataframe_mlt = dataframe_mlt

        # List for answer indices for each question (each question has 10 answers)
        self.answer_index_per_question = []

        # Transforming the answers and answer types to one hot encoded vectors
        self.answer_onehotencoded = answer_onehotencoder.transform(self.dataframe[['answer']]).toarray()
        self.answer_type_onehotencoded = answer_type_onehotencoder.transform(self.dataframe[['answer_type']]).toarray()

        # Saving the answer categories (vocabulary) which will be used when getting index of the predicted answer
        self.answers_categories = answer_onehotencoder.categories_[0].tolist()

        # Saving answer indices for each question (each question has 10 answers)
        self.build_answer_index_per_question()

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, index):
        answer = torch.tensor(self.answer_onehotencoded[index], dtype=torch.float32)
        answer_type = torch.tensor(self.answer_type_onehotencoded[index], dtype=torch.float32)
        answer_indices = torch.tensor(self.answer_index_per_question[index], dtype=torch.long)
        answerable = torch.tensor(self.answerable[index], dtype=torch.float32)
        return self.images_features[index], self.questions_features[index], answer, answer_type, answer_indices, answerable

    def build_answer_index_per_question(self):
        for index, row in self.dataframe_mlt.iterrows():
            temp_list = []
            for answer_map in row['answers']:
                answer = answer_map['answer']
                # check if answer in self.answers_categories
                if answer in self.answers_categories:
                    answer_index = self.answers_categories.index(answer)
                    temp_list.append(answer_index)
            # Torch.tensor requires the all the lists to have constant length, so we pad the list with -1 if needed
            while len(temp_list) < 10:
                temp_list.append(-1)
            self.answer_index_per_question.append(temp_list)

# %% [markdown]
# ## Preparing dataloaders

# %%
# Constructing the training dataset
training_dataset = VizWizDataset(train_df_final, train_df, training_images, training_questions, answer_type_encoder, answer_encoder)

# Constructing the validation dataset
validation_dataset = VizWizDataset(val_df_final, val_df, validation_images, validation_questions, answer_type_encoder, answer_encoder)

# %%
# Configuring the data loaders  for comparative analysis
BATCH_SIZE = 32 # 64 is good too but 32 is better (variance wise)

# Constructing the training and validation data loaders
training_dataloader = DataLoader(training_dataset, batch_size=BATCH_SIZE, shuffle=True)
validation_dataloader = DataLoader(validation_dataset, batch_size=BATCH_SIZE)

# %% [markdown]
# ## Building The VQA Model's Architecture

# %%
class VQAModel(nn.Module):

    def __init__(self, num_classes, hidden_size=512, dropout_rate=0.5, FT=False, device = torch.device("cpu")):
        
        super(VQAModel, self).__init__()

        self.training_losses = []
        self.validation_losses = []

        self.training_accuracies = []
        self.validation_accuracies = []

        self.vizwiz_training_accuracies = []
        self.vizwiz_validation_accuracies = []
        
        self.device = device
        self.FT = FT

        # First linear layer
        self.linear_layer1 = nn.Sequential(
            nn.LayerNorm(1024 + 1024),
            nn.Dropout(p=0.5),
            nn.Linear(1024 + 1024, hidden_size)
        )

        # Second linear layer
        self.linear_layer2 = nn.Sequential(
            nn.LayerNorm(hidden_size),
            nn.Dropout(p=0.5),
            nn.Linear(hidden_size, num_classes) 
        )

    def forward(self, image, question):
        # Concatenating the image and question features
        features = torch.cat((image, question), dim=1)
        
        # Passing the features through the first linear layer
        features = self.linear_layer1(features)
        # Passing the features through the second linear layer
        output = self.linear_layer2(features)
        
        return output

    def train_model(self, training_dataloader, validation_dataloader, criterion, optimizer, epochs = 10, save_path = None):
        for epoch in range(1,epochs+1):
            training_loss, training_accuracy, training_vizwiz_accuracy = self.training_step(training_dataloader, criterion, optimizer, self.device)
            
            if self.FT == False or epoch == epochs:
                validation_loss, validation_accuracy, validation_vizwiz_accuracy = self.validation_step(validation_dataloader, criterion, self.device)
                self.validation_losses.append(validation_loss)
                self.validation_accuracies.append(validation_accuracy)
                self.vizwiz_validation_accuracies.append(validation_vizwiz_accuracy)

                self.training_losses.append(training_loss)
                self.training_accuracies.append(training_accuracy)
                self.vizwiz_training_accuracies.append(training_vizwiz_accuracy)
                
            if self.FT == False:
                print(f"Epoch: {epoch} | Training Loss: {training_loss:.3f} | Validation Loss: {validation_loss:.3f}")
                print(f"Epoch: {epoch} | Training Accuracy: {training_accuracy:.3f} | Validation Accuracy: {validation_accuracy:.3f}")
                print(f"Epoch: {epoch} | Training VizWiz Accuracy: {training_vizwiz_accuracy:.3f} | Validation VizWiz Accuracy: {validation_vizwiz_accuracy:.3f}\n")
            
                if save_path != None and epoch == epochs:
                    self.save_model(save_path + "epoch_{}.pth".format(epoch))
            else:
                print(f"Epoch: {epoch}")

        if self.FT == True:
            return self.validation_losses[-1]
            
        self.evaluation_step(validation_dataloader, criterion, self.device)
        
        return

    def training_step(self, dataloader, criterion, optimizer, device):
        training_loss, training_accuracy, vizwiz_accuracy, total_sum = 0.0, 0.0, 0.0, 0
        self.train()
        for _, batch in tqdm(enumerate(dataloader), total=len(dataloader)):
            image, question, answer, answer_type, answers_for_questions, answerable = batch
            image, question, answer, answer_type, answers_for_questions, answerable = image.to(device), question.to(device), answer.to(device), answer_type.to(device), answers_for_questions.to(device), answerable.to(device)
            optimizer.zero_grad()
            output = self.forward(image, question)
            loss = criterion(output, answer)
            loss.backward()
            optimizer.step()
            training_loss += loss.item()
            predicted_answer = torch.argmax(output, dim = 1)
            actual_answer = torch.argmax(answer, dim = 1)
            for i in range(len(answer)):
                if actual_answer[i] == predicted_answer[i]:
                    training_accuracy +=1
                total_sum +=1
                vizwiz_accuracy += min(1, torch.sum(torch.eq(predicted_answer[i], answers_for_questions[i])).item()/3)

        training_loss /= len(dataloader)
        training_accuracy /= total_sum
        vizwiz_accuracy /= total_sum
        
        return training_loss, training_accuracy, vizwiz_accuracy
        
    def validation_step(self, dataloader, criterion, device):
        validation_loss, validation_accuracy, vizwiz_accuracy, total_sum = 0.0, 0.0, 0.0, 0
        self.eval()
        with torch.no_grad():
            for _, batch in tqdm(enumerate(dataloader), total=len(dataloader)):
                image, question, answer, answer_type, answers_for_questions, answerable = batch
                image, question, answer, answer_type, answers_for_questions, answerable = image.to(device), question.to(device), answer.to(device), answer_type.to(device), answers_for_questions.to(device), answerable.to(device)
                output = self.forward(image, question)
                loss = criterion(output, answer)
                validation_loss += loss.item()
                predicted_answer = torch.argmax(output, dim = 1)
                actual_answer = torch.argmax(answer, dim = 1)
                for i in range(len(answer)):
                    if torch.sum(answer[i]) == 0:
                        continue
                    if actual_answer[i] == predicted_answer[i]:
                        validation_accuracy += 1
                    total_sum +=1
                    vizwiz_accuracy += min(1, torch.sum(torch.eq(predicted_answer[i], answers_for_questions[i])).item()/3)
        
        validation_loss /= len(dataloader)
        validation_accuracy /= total_sum
        vizwiz_accuracy /= total_sum
        
        return validation_loss, validation_accuracy, vizwiz_accuracy

    def evaluation_step(self, dataloader, criterion, device):
        self.eval()
    
        total_loss, total_correct, total_vizwiz, total_samples = 0.0, 0, 0, 0
    
        types = ['number', 'other', 'unanswerable', 'yes/no']
        type_correct = {t: 0 for t in types}
        type_total = {t: 0 for t in types}
        type_vizwiz = {t: 0.0 for t in types}
    
        with torch.no_grad():
            for _, batch in tqdm(enumerate(dataloader), total=len(dataloader)):
                image, question, answer, answer_type, answers_for_questions, answerable = batch
                image, question = image.to(device), question.to(device)
                answer = answer.to(device)
                answer_type = answer_type.to(device)
                answers_for_questions = answers_for_questions.to(device)
                answerable = answerable.to(device)
    
                # output, answerable_predict = self.forward(image, question)
                output = self.forward(image, question)
                loss = criterion(output, answer)
                total_loss += loss.item()
    
                predicted_answer = torch.argmax(output, dim=1)
                actual_answer = torch.argmax(answer, dim=1)
    
                for i in range(answer.size(0)):
                    if torch.sum(answer[i]) == 0:
                        continue  # Skip invalid samples
    
                    total_samples += 1
                    type_index = torch.argmax(answer_type[i]).item()
                    type_str = types[type_index]
                    type_total[type_str] += 1
    
                    if predicted_answer[i] == actual_answer[i]:
                        total_correct += 1
                        type_correct[type_str] += 1
    
                    # VizWiz accuracy (max 1 if 3/3 match, otherwise partial)
                    viz_acc = min(1, torch.sum(predicted_answer[i] == answers_for_questions[i]).item() / 3)
                    total_vizwiz += viz_acc
                    type_vizwiz[type_str] += viz_acc
    
        val_loss = total_loss / len(dataloader)
        val_accuracy = total_correct / total_samples
        vizwiz_accuracy = total_vizwiz / total_samples
    
        # Per-type metrics
        per_type_metrics = {}
        for t in types:
            if type_total[t] > 0:
                per_type_metrics[t] = {
                    "accuracy": type_correct[t] / type_total[t],
                    "vizwiz_accuracy": type_vizwiz[t] / type_total[t]
                }
            else:
                per_type_metrics[t] = {
                    "accuracy": 0.0,
                    "vizwiz_accuracy": 0.0
                }
    
        # Print per-type metrics
        type_table = []
        for t in types:
            type_table.append([
                t.upper(),
                f"{per_type_metrics[t]['accuracy']:.4f}",
                f"{per_type_metrics[t]['vizwiz_accuracy']:.4f}"
            ])
        
        print("\nPer-Type Metrics:")
        print(tabulate(type_table, headers=["Answer Type", "Accuracy", "VizWiz Accuracy"], tablefmt="grid"))
        
        # Print overall metrics
        overall_table = [
            ["Validation Loss", f"{val_loss:.4f}"],
            ["Validation Accuracy", f"{val_accuracy:.4f}"],
            ["VizWiz Accuracy", f"{vizwiz_accuracy:.4f}"]
        ]
        
        print("\nOverall Validation Metrics:")
        print(tabulate(overall_table, headers=["Metric", "Value"], tablefmt="grid"))
        
    def save_model(self, path):
        """
        Saves the model state dictionary to the given path.

        Args:
        - self: the model object
        - path (str): the path to save the model state dictionary

        Returns:
        - None
        """
        torch.save(self.state_dict(), path)

    def load_model(self, path):
        """
        Loads the model state dictionary from the given path.

        Args:
        - self: the model object
        - path (str): the path to load the model state dictionary

        Returns:
        - self: the loaded model object
        """
        self.load_state_dict(torch.load(path))
        self.eval()
        return self

    def predict(self, image, question):
        """
        Predicts the output and answer type for the given image and question.

        Args:
        - self: the model object
        - image (tensor): the image tensor
        - question (tensor): the question tensor

        Returns:
        - output (tensor): the predicted output tensor
        """
        output = self.forward(image, question)
        return output

    def plot_loss(self):
        """
        Plots the training and validation losses.

        Args:
        - self: the model object

        Returns:
        - None
        """
        plt.plot(self.training_losses, label = "Training Loss")
        plt.plot(self.validation_losses, label = "Validation Loss")
        plt.legend()
        plt.show()

    def plot_accuracy(self):
        """
        Plots the training and validation accuracies.

        Args:
        - self: the model object

        Returns:
        - None
        """
        plt.plot(self.training_accuracies, label = "Training Accuracy")
        plt.plot(self.validation_accuracies, label = "Validation Accuracy")
        plt.legend()
        plt.show()

    def plot_vizwiz_accuracy(self):
        """
        Plots the VizWiz training and validation accuracies.

        Args:
        - self: the model object

        Returns:
        - None
        """
        plt.plot(self.vizwiz_training_accuracies, label = "VizWiz Training Accuracy")
        plt.plot(self.vizwiz_validation_accuracies, label = "VizWiz Validation Accuracy")
        plt.legend()
        plt.show()

# %% [markdown]
# ## Training the VQA Model

# %%
# Configuring training's hyperparameters for comparative analysis
NUM_EPOCHS = 30
LR = 1e-4
WEIGHT_DECAY = 1e-3
SAVE_PATH = OUTPUT_PATH

# Initializing the model
model = VQAModel(num_classes=NUM_CLASSES, device= DEVICE, hidden_size=512).to(DEVICE)

# Initializing the loss function and optimizer
loss_function = nn.CrossEntropyLoss().to(DEVICE)
optimizer = optim.Adam(model.parameters(), lr=LR, weight_decay = WEIGHT_DECAY)

# Training the model and plotting the loss and accuracy
model.train_model(training_dataloader, validation_dataloader, loss_function, optimizer, epochs=NUM_EPOCHS, save_path=SAVE_PATH)
model.plot_loss()
model.plot_accuracy()
model.plot_vizwiz_accuracy()
# Out:
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 1 | Training Loss: 5.139 | Validation Loss: 4.479
# Epoch: 1 | Training Accuracy: 0.395 | Validation Accuracy: 0.469
# Epoch: 1 | Training VizWiz Accuracy: 0.476 | Validation VizWiz Accuracy: 0.546
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 2 | Training Loss: 4.539 | Validation Loss: 4.274
# Epoch: 2 | Training Accuracy: 0.408 | Validation Accuracy: 0.480
# Epoch: 2 | Training VizWiz Accuracy: 0.491 | Validation VizWiz Accuracy: 0.558
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 3 | Training Loss: 4.282 | Validation Loss: 4.119
# Epoch: 3 | Training Accuracy: 0.421 | Validation Accuracy: 0.487
# Epoch: 3 | Training VizWiz Accuracy: 0.501 | Validation VizWiz Accuracy: 0.567
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 4 | Training Loss: 4.065 | Validation Loss: 3.983
# Epoch: 4 | Training Accuracy: 0.433 | Validation Accuracy: 0.497
# Epoch: 4 | Training VizWiz Accuracy: 0.514 | Validation VizWiz Accuracy: 0.578
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 5 | Training Loss: 3.881 | Validation Loss: 3.853
# Epoch: 5 | Training Accuracy: 0.444 | Validation Accuracy: 0.509
# Epoch: 5 | Training VizWiz Accuracy: 0.522 | Validation VizWiz Accuracy: 0.588
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 6 | Training Loss: 3.703 | Validation Loss: 3.765
# Epoch: 6 | Training Accuracy: 0.458 | Validation Accuracy: 0.516
# Epoch: 6 | Training VizWiz Accuracy: 0.535 | Validation VizWiz Accuracy: 0.598
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 7 | Training Loss: 3.550 | Validation Loss: 3.694
# Epoch: 7 | Training Accuracy: 0.467 | Validation Accuracy: 0.523
# Epoch: 7 | Training VizWiz Accuracy: 0.545 | Validation VizWiz Accuracy: 0.604
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 8 | Training Loss: 3.415 | Validation Loss: 3.646
# Epoch: 8 | Training Accuracy: 0.474 | Validation Accuracy: 0.526
# Epoch: 8 | Training VizWiz Accuracy: 0.551 | Validation VizWiz Accuracy: 0.607
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 9 | Training Loss: 3.275 | Validation Loss: 3.624
# Epoch: 9 | Training Accuracy: 0.483 | Validation Accuracy: 0.534
# Epoch: 9 | Training VizWiz Accuracy: 0.559 | Validation VizWiz Accuracy: 0.616
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 10 | Training Loss: 3.161 | Validation Loss: 3.543
# Epoch: 10 | Training Accuracy: 0.495 | Validation Accuracy: 0.536
# Epoch: 10 | Training VizWiz Accuracy: 0.570 | Validation VizWiz Accuracy: 0.618
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 11 | Training Loss: 3.046 | Validation Loss: 3.478
# Epoch: 11 | Training Accuracy: 0.504 | Validation Accuracy: 0.536
# Epoch: 11 | Training VizWiz Accuracy: 0.577 | Validation VizWiz Accuracy: 0.618
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 12 | Training Loss: 2.949 | Validation Loss: 3.469
# Epoch: 12 | Training Accuracy: 0.508 | Validation Accuracy: 0.541
# Epoch: 12 | Training VizWiz Accuracy: 0.583 | Validation VizWiz Accuracy: 0.624
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 13 | Training Loss: 2.844 | Validation Loss: 3.445
# Epoch: 13 | Training Accuracy: 0.517 | Validation Accuracy: 0.542
# Epoch: 13 | Training VizWiz Accuracy: 0.592 | Validation VizWiz Accuracy: 0.624
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 14 | Training Loss: 2.748 | Validation Loss: 3.422
# Epoch: 14 | Training Accuracy: 0.524 | Validation Accuracy: 0.544
# Epoch: 14 | Training VizWiz Accuracy: 0.598 | Validation VizWiz Accuracy: 0.626
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 15 | Training Loss: 2.664 | Validation Loss: 3.382
# Epoch: 15 | Training Accuracy: 0.530 | Validation Accuracy: 0.545
# Epoch: 15 | Training VizWiz Accuracy: 0.603 | Validation VizWiz Accuracy: 0.628
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 16 | Training Loss: 2.573 | Validation Loss: 3.365
# Epoch: 16 | Training Accuracy: 0.539 | Validation Accuracy: 0.550
# Epoch: 16 | Training VizWiz Accuracy: 0.610 | Validation VizWiz Accuracy: 0.634
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 17 | Training Loss: 2.503 | Validation Loss: 3.337
# Epoch: 17 | Training Accuracy: 0.544 | Validation Accuracy: 0.551
# Epoch: 17 | Training VizWiz Accuracy: 0.615 | Validation VizWiz Accuracy: 0.633
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 18 | Training Loss: 2.419 | Validation Loss: 3.320
# Epoch: 18 | Training Accuracy: 0.548 | Validation Accuracy: 0.547
# Epoch: 18 | Training VizWiz Accuracy: 0.619 | Validation VizWiz Accuracy: 0.630
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 19 | Training Loss: 2.342 | Validation Loss: 3.310
# Epoch: 19 | Training Accuracy: 0.555 | Validation Accuracy: 0.555
# Epoch: 19 | Training VizWiz Accuracy: 0.625 | Validation VizWiz Accuracy: 0.637
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 20 | Training Loss: 2.267 | Validation Loss: 3.299
# Epoch: 20 | Training Accuracy: 0.565 | Validation Accuracy: 0.558
# Epoch: 20 | Training VizWiz Accuracy: 0.631 | Validation VizWiz Accuracy: 0.642
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 21 | Training Loss: 2.194 | Validation Loss: 3.267
# Epoch: 21 | Training Accuracy: 0.574 | Validation Accuracy: 0.553
# Epoch: 21 | Training VizWiz Accuracy: 0.640 | Validation VizWiz Accuracy: 0.636
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 22 | Training Loss: 2.132 | Validation Loss: 3.273
# Epoch: 22 | Training Accuracy: 0.577 | Validation Accuracy: 0.557
# Epoch: 22 | Training VizWiz Accuracy: 0.641 | Validation VizWiz Accuracy: 0.641
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 23 | Training Loss: 2.070 | Validation Loss: 3.259
# Epoch: 23 | Training Accuracy: 0.581 | Validation Accuracy: 0.558
# Epoch: 23 | Training VizWiz Accuracy: 0.647 | Validation VizWiz Accuracy: 0.643
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 24 | Training Loss: 2.005 | Validation Loss: 3.264
# Epoch: 24 | Training Accuracy: 0.585 | Validation Accuracy: 0.560
# Epoch: 24 | Training VizWiz Accuracy: 0.650 | Validation VizWiz Accuracy: 0.644
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 25 | Training Loss: 1.935 | Validation Loss: 3.279
# Epoch: 25 | Training Accuracy: 0.597 | Validation Accuracy: 0.560
# Epoch: 25 | Training VizWiz Accuracy: 0.661 | Validation VizWiz Accuracy: 0.643
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 26 | Training Loss: 1.887 | Validation Loss: 3.242
# Epoch: 26 | Training Accuracy: 0.602 | Validation Accuracy: 0.557
# Epoch: 26 | Training VizWiz Accuracy: 0.664 | Validation VizWiz Accuracy: 0.643
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 27 | Training Loss: 1.831 | Validation Loss: 3.211
# Epoch: 27 | Training Accuracy: 0.607 | Validation Accuracy: 0.558
# Epoch: 27 | Training VizWiz Accuracy: 0.667 | Validation VizWiz Accuracy: 0.644
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 28 | Training Loss: 1.768 | Validation Loss: 3.199
# Epoch: 28 | Training Accuracy: 0.618 | Validation Accuracy: 0.563
# Epoch: 28 | Training VizWiz Accuracy: 0.678 | Validation VizWiz Accuracy: 0.647
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 29 | Training Loss: 1.718 | Validation Loss: 3.214
# Epoch: 29 | Training Accuracy: 0.617 | Validation Accuracy: 0.567
# Epoch: 29 | Training VizWiz Accuracy: 0.677 | Validation VizWiz Accuracy: 0.650
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 30 | Training Loss: 1.672 | Validation Loss: 3.193
# Epoch: 30 | Training Accuracy: 0.627 | Validation Accuracy: 0.569
# Epoch: 30 | Training VizWiz Accuracy: 0.684 | Validation VizWiz Accuracy: 0.653
#   0%|          | 0/135 [00:00<?, ?it/s]
# Per-Type Metrics:
# +---------------+------------+-------------------+
# | Answer Type   |   Accuracy |   VizWiz Accuracy |
# +===============+============+===================+
# | NUMBER        |     0.25   |            0.4028 |
# +---------------+------------+-------------------+
# | OTHER         |     0.3828 |            0.492  |
# +---------------+------------+-------------------+
# | UNANSWERABLE  |     0.9639 |            0.9747 |
# +---------------+------------+-------------------+
# | YES/NO        |     0.4051 |            0.6547 |
# +---------------+------------+-------------------+
#
# Overall Validation Metrics:
# +---------------------+---------+
# | Metric              |   Value |
# +=====================+=========+
# | Validation Loss     |  3.1925 |
# +---------------------+---------+
# | Validation Accuracy |  0.5687 |
# +---------------------+---------+
# | VizWiz Accuracy     |  0.6532 |
# +---------------------+---------+

# %% [markdown]
# ## Building The AP Model's Architecture

# %%
class APModel(nn.Module):

    def __init__(self, hidden_size=512, dropout_rate=0.5, FT=False, device = torch.device("cpu")):
        
        super(APModel, self).__init__()
        
        self.training_losses = []
        self.validation_losses = []
        
        self.training_answerability = []
        self.validation_answerability = []
        
        self.device = device
        self.FT = FT
        
        # Initializing Binary Cross Entropy Loss which will be used to train the model on answerability
        self.answerability_loss_fn = nn.BCELoss()

        # First linear layer
        self.linear_layer1 = nn.Sequential(
            nn.LayerNorm(1024 + 1024),
            nn.Dropout(p=0.5),
            nn.Linear(1024 + 1024, hidden_size)
        )

        # Second linear layer
        self.linear_layer2 = nn.Sequential(
            nn.LayerNorm(hidden_size),
            # nn.Dropout(p=0.5),
            nn.Linear(hidden_size, 1) 
        )

        self.answerability_sigmoid = nn.Sigmoid()

    def forward(self, image, question):
        # Concatenating the image and question features
        features = torch.cat((image, question), dim=1)
        
        # Passing the features through the first linear layer
        features = self.linear_layer1(features)
        # Passing the features through the second linear layer
        output = self.linear_layer2(features)
        output = self.answerability_sigmoid(output)
        output = output.squeeze()
        
        return output

    def train_model(self, training_dataloader, validation_dataloader, optimizer, epochs = 10, save_path = None):
        for epoch in range(1,epochs+1):
            training_loss, train_answerability_score = self.training_step(training_dataloader, optimizer, self.device)

            if self.FT == False or epoch == epochs:
                validation_loss, validation_answerability_score = self.validation_step(validation_dataloader, self.device)
                self.validation_losses.append(validation_loss)
                self.validation_answerability.append(validation_answerability_score)

                self.training_losses.append(training_loss) 
                self.training_answerability.append(train_answerability_score)
                
            if self.FT == False:
                print(f"Epoch: {epoch} | Training Loss: {training_loss:.3f} | Validation Loss: {validation_loss:.3f}")
                print(f"Epoch: {epoch} | Training Answerability Score: {train_answerability_score:.3f} | Validation Answerability Score: {validation_answerability_score:.3f}\n")
            
                if save_path != None and epoch == epochs:
                    self.save_model(save_path + "ap_epoch_{}.pth".format(epoch))
            else:
                print(f"Epoch: {epoch}")
                
        if self.FT == True:
            return self.validation_losses[-1]
            
        return

    def training_step(self, dataloader, optimizer, device):
        training_loss = 0.0
        answerable_true = []
        answerable_predicted = []
        self.train()
        for _, batch in tqdm(enumerate(dataloader), total=len(dataloader)):
            image, question, answer, answer_type, answers_for_questions, answerable = batch
            image, question, answer, answer_type, answers_for_questions, answerable = image.to(device), question.to(device), answer.to(device), answer_type.to(device), answers_for_questions.to(device), answerable.to(device)
            optimizer.zero_grad()
            answerable_predict = self.forward(image, question)
            loss = self.answerability_loss_fn(answerable_predict, answerable)
            loss.backward()
            optimizer.step()
            training_loss += loss.item()
            for i in range(len(answer)):
                answerable_true.append(answerable[i].item())
                answerable_predicted.append(answerable_predict[i].item())

        answerable_true = np.array(answerable_true)
        answerable_predicted = np.array(answerable_predicted)
        training_loss /= len(dataloader)
        
        return training_loss, average_precision_score(answerable_true, answerable_predicted, average = 'weighted')
        
    def validation_step(self, dataloader, device):
        validation_loss = 0.0
        answerable_true = []
        answerable_predicted = []
        self.eval()
        with torch.no_grad():
            for _, batch in tqdm(enumerate(dataloader), total=len(dataloader)):
                image, question, answer, answer_type, answers_for_questions, answerable = batch
                image, question, answer, answer_type, answers_for_questions, answerable = image.to(device), question.to(device), answer.to(device), answer_type.to(device), answers_for_questions.to(device), answerable.to(device)
                answerable_predict = self.forward(image, question)
                loss = self.answerability_loss_fn(answerable_predict, answerable)
                validation_loss += loss.item()
                for i in range(len(answer)):
                    answerable_true.append(answerable[i].item())
                    answerable_predicted.append(answerable_predict[i].item())
                    
        answerable_true = np.array(answerable_true)
        answerable_predicted = np.array(answerable_predicted)
        validation_loss /= len(dataloader)
        
        # We will use weighted average since that there is imbalance in answerability in the dataset as displayed in EDA section
        return validation_loss, average_precision_score(answerable_true, answerable_predicted, average = 'weighted')
        
    def save_model(self, path):
        """
        Saves the model state dictionary to the given path.

        Args:
        - self: the model object
        - path (str): the path to save the model state dictionary

        Returns:
        - None
        """
        torch.save(self.state_dict(), path)

    def load_model(self, path):
        """
        Loads the model state dictionary from the given path.

        Args:
        - self: the model object
        - path (str): the path to load the model state dictionary

        Returns:
        - self: the loaded model object
        """
        self.load_state_dict(torch.load(path))
        self.eval()
        return self

    def predict(self, image, question):
        """
        Predicts the output and answer type for the given image and question.

        Args:
        - self: the model object
        - image (tensor): the image tensor
        - question (tensor): the question tensor

        Returns:
        - output (tensor): the predicted output tensor
        """
        output = self.forward(image, question)
        return output

    def plot_loss(self):
        """
        Plots the training and validation losses.

        Args:
        - self: the model object

        Returns:
        - None
        """
        plt.plot(self.training_losses, label = "Training Loss")
        plt.plot(self.validation_losses, label = "Validation Loss")
        plt.legend()
        plt.show()

    def plot_answerability(self):
        """
        Plots the training and validation answerabilities.

        Args:
        - self: the model object

        Returns:
        - None
        """
        plt.plot(self.training_answerability, label = "Training Answerability")
        plt.plot(self.validation_answerability, label = "Validation Answerability")
        plt.legend()
        plt.show()

# %% [markdown]
# ## Training the AP Model

# %%
# Configuring training's hyperparameters for comparative analysis
NUM_EPOCHS = 50
LR = 1e-4
WEIGHT_DECAY = 0
SAVE_PATH = OUTPUT_PATH

# Initializing the model
ap_model = APModel(device= DEVICE, hidden_size=512).to(DEVICE)

# Initializing the optimizer
ap_optimizer = optim.Adam(ap_model.parameters(), lr=LR, weight_decay = WEIGHT_DECAY)

# Training the model and plotting the loss and accuracy
ap_model.train_model(training_dataloader, validation_dataloader, ap_optimizer, epochs=NUM_EPOCHS, save_path=SAVE_PATH)
ap_model.plot_loss()
ap_model.plot_answerability()
# Out:
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 1 | Training Loss: 0.428 | Validation Loss: 0.415
# Epoch: 1 | Training Answerability Score: 0.927 | Validation Answerability Score: 0.938
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 2 | Training Loss: 0.391 | Validation Loss: 0.395
# Epoch: 2 | Training Answerability Score: 0.943 | Validation Answerability Score: 0.941
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 3 | Training Loss: 0.382 | Validation Loss: 0.413
# Epoch: 3 | Training Answerability Score: 0.947 | Validation Answerability Score: 0.939
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 4 | Training Loss: 0.383 | Validation Loss: 0.437
# Epoch: 4 | Training Answerability Score: 0.947 | Validation Answerability Score: 0.936
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 5 | Training Loss: 0.377 | Validation Loss: 0.394
# Epoch: 5 | Training Answerability Score: 0.948 | Validation Answerability Score: 0.941
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 6 | Training Loss: 0.376 | Validation Loss: 0.405
# Epoch: 6 | Training Answerability Score: 0.949 | Validation Answerability Score: 0.940
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 7 | Training Loss: 0.370 | Validation Loss: 0.401
# Epoch: 7 | Training Answerability Score: 0.952 | Validation Answerability Score: 0.941
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 8 | Training Loss: 0.371 | Validation Loss: 0.407
# Epoch: 8 | Training Answerability Score: 0.951 | Validation Answerability Score: 0.942
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 9 | Training Loss: 0.368 | Validation Loss: 0.394
# Epoch: 9 | Training Answerability Score: 0.952 | Validation Answerability Score: 0.944
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 10 | Training Loss: 0.366 | Validation Loss: 0.415
# Epoch: 10 | Training Answerability Score: 0.953 | Validation Answerability Score: 0.943
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 11 | Training Loss: 0.366 | Validation Loss: 0.394
# Epoch: 11 | Training Answerability Score: 0.953 | Validation Answerability Score: 0.944
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 12 | Training Loss: 0.367 | Validation Loss: 0.395
# Epoch: 12 | Training Answerability Score: 0.954 | Validation Answerability Score: 0.944
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 13 | Training Loss: 0.365 | Validation Loss: 0.392
# Epoch: 13 | Training Answerability Score: 0.955 | Validation Answerability Score: 0.944
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 14 | Training Loss: 0.363 | Validation Loss: 0.387
# Epoch: 14 | Training Answerability Score: 0.955 | Validation Answerability Score: 0.944
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 15 | Training Loss: 0.359 | Validation Loss: 0.395
# Epoch: 15 | Training Answerability Score: 0.957 | Validation Answerability Score: 0.943
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 16 | Training Loss: 0.356 | Validation Loss: 0.388
# Epoch: 16 | Training Answerability Score: 0.958 | Validation Answerability Score: 0.944
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 17 | Training Loss: 0.357 | Validation Loss: 0.383
# Epoch: 17 | Training Answerability Score: 0.957 | Validation Answerability Score: 0.945
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 18 | Training Loss: 0.357 | Validation Loss: 0.404
# Epoch: 18 | Training Answerability Score: 0.958 | Validation Answerability Score: 0.945
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 19 | Training Loss: 0.355 | Validation Loss: 0.391
# Epoch: 19 | Training Answerability Score: 0.959 | Validation Answerability Score: 0.944
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 20 | Training Loss: 0.354 | Validation Loss: 0.388
# Epoch: 20 | Training Answerability Score: 0.959 | Validation Answerability Score: 0.945
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 21 | Training Loss: 0.352 | Validation Loss: 0.386
# Epoch: 21 | Training Answerability Score: 0.959 | Validation Answerability Score: 0.946
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 22 | Training Loss: 0.354 | Validation Loss: 0.389
# Epoch: 22 | Training Answerability Score: 0.959 | Validation Answerability Score: 0.946
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 23 | Training Loss: 0.352 | Validation Loss: 0.387
# Epoch: 23 | Training Answerability Score: 0.960 | Validation Answerability Score: 0.946
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 24 | Training Loss: 0.351 | Validation Loss: 0.394
# Epoch: 24 | Training Answerability Score: 0.960 | Validation Answerability Score: 0.947
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 25 | Training Loss: 0.348 | Validation Loss: 0.384
# Epoch: 25 | Training Answerability Score: 0.961 | Validation Answerability Score: 0.947
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 26 | Training Loss: 0.348 | Validation Loss: 0.384
# Epoch: 26 | Training Answerability Score: 0.961 | Validation Answerability Score: 0.946
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 27 | Training Loss: 0.348 | Validation Loss: 0.384
# Epoch: 27 | Training Answerability Score: 0.961 | Validation Answerability Score: 0.947
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 28 | Training Loss: 0.345 | Validation Loss: 0.392
# Epoch: 28 | Training Answerability Score: 0.962 | Validation Answerability Score: 0.947
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 29 | Training Loss: 0.343 | Validation Loss: 0.388
# Epoch: 29 | Training Answerability Score: 0.963 | Validation Answerability Score: 0.946
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 30 | Training Loss: 0.344 | Validation Loss: 0.389
# Epoch: 30 | Training Answerability Score: 0.962 | Validation Answerability Score: 0.947
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 31 | Training Loss: 0.345 | Validation Loss: 0.392
# Epoch: 31 | Training Answerability Score: 0.962 | Validation Answerability Score: 0.947
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 32 | Training Loss: 0.340 | Validation Loss: 0.404
# Epoch: 32 | Training Answerability Score: 0.964 | Validation Answerability Score: 0.947
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 33 | Training Loss: 0.339 | Validation Loss: 0.384
# Epoch: 33 | Training Answerability Score: 0.964 | Validation Answerability Score: 0.948
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 34 | Training Loss: 0.338 | Validation Loss: 0.385
# Epoch: 34 | Training Answerability Score: 0.964 | Validation Answerability Score: 0.948
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 35 | Training Loss: 0.338 | Validation Loss: 0.386
# Epoch: 35 | Training Answerability Score: 0.965 | Validation Answerability Score: 0.947
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 36 | Training Loss: 0.336 | Validation Loss: 0.395
# Epoch: 36 | Training Answerability Score: 0.965 | Validation Answerability Score: 0.947
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 37 | Training Loss: 0.334 | Validation Loss: 0.380
# Epoch: 37 | Training Answerability Score: 0.966 | Validation Answerability Score: 0.948
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 38 | Training Loss: 0.333 | Validation Loss: 0.387
# Epoch: 38 | Training Answerability Score: 0.966 | Validation Answerability Score: 0.948
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 39 | Training Loss: 0.331 | Validation Loss: 0.395
# Epoch: 39 | Training Answerability Score: 0.967 | Validation Answerability Score: 0.949
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 40 | Training Loss: 0.327 | Validation Loss: 0.381
# Epoch: 40 | Training Answerability Score: 0.968 | Validation Answerability Score: 0.949
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 41 | Training Loss: 0.327 | Validation Loss: 0.386
# Epoch: 41 | Training Answerability Score: 0.968 | Validation Answerability Score: 0.949
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 42 | Training Loss: 0.326 | Validation Loss: 0.388
# Epoch: 42 | Training Answerability Score: 0.968 | Validation Answerability Score: 0.949
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 43 | Training Loss: 0.328 | Validation Loss: 0.382
# Epoch: 43 | Training Answerability Score: 0.967 | Validation Answerability Score: 0.949
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 44 | Training Loss: 0.322 | Validation Loss: 0.381
# Epoch: 44 | Training Answerability Score: 0.969 | Validation Answerability Score: 0.949
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 45 | Training Loss: 0.320 | Validation Loss: 0.386
# Epoch: 45 | Training Answerability Score: 0.970 | Validation Answerability Score: 0.949
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 46 | Training Loss: 0.317 | Validation Loss: 0.392
# Epoch: 46 | Training Answerability Score: 0.970 | Validation Answerability Score: 0.949
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 47 | Training Loss: 0.314 | Validation Loss: 0.385
# Epoch: 47 | Training Answerability Score: 0.971 | Validation Answerability Score: 0.949
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 48 | Training Loss: 0.310 | Validation Loss: 0.400
# Epoch: 48 | Training Answerability Score: 0.972 | Validation Answerability Score: 0.949
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 49 | Training Loss: 0.310 | Validation Loss: 0.384
# Epoch: 49 | Training Answerability Score: 0.972 | Validation Answerability Score: 0.950
#   0%|          | 0/642 [00:00<?, ?it/s]
#   0%|          | 0/135 [00:00<?, ?it/s]
# Epoch: 50 | Training Loss: 0.305 | Validation Loss: 0.385
# Epoch: 50 | Training Answerability Score: 0.973 | Validation Answerability Score: 0.949

# %% [markdown]
# ## Inference (Testing split)

# %%
class VizWizTestDataset(Dataset):
    def __init__(self, dataframe, images_features, questions_features):
        
        super(VizWizTestDataset, self).__init__()

        # Saving image & question embeddings
        self.images_features = images_features
        self.questions_features = questions_features

        # Saving the dataframe and answer encoder
        self.dataframe = dataframe

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, index):
        return self.images_features[index], self.questions_features[index], self.dataframe.iloc[index].image

# %%
# Constructing the test dataloader
test_dataset = VizWizTestDataset(test_df, test_images, test_questions)
test_dataloader = DataLoader(test_dataset, batch_size=1)

# %% [markdown]
# ### Inference for the VQA Model

# %%
# epoch = vqa_best_params['num_epochs']
epoch = 30
# model = VQAModel(num_classes=NUM_CLASSES, device= DEVICE, dropout_rate=vqa_best_params['dropout_rate'], hidden_size=vqa_best_params['fc_layer_size']).to(DEVICE)
model = VQAModel(num_classes=NUM_CLASSES, device=DEVICE).to(DEVICE)
model.load_model(OUTPUT_PATH + "epoch_{}.pth".format(epoch))
# Out:
# VQAModel(
#   (linear_layer1): Sequential(
#     (0): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#     (1): Dropout(p=0.5, inplace=False)
#     (2): Linear(in_features=2048, out_features=512, bias=True)
#   )
#   (linear_layer2): Sequential(
#     (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     (1): Dropout(p=0.5, inplace=False)
#     (2): Linear(in_features=512, out_features=5545, bias=True)
#   )
# )

# %%
def get_all_test_inference(model, test_dataloader, device):
    """
    Obtains VQA inferences for all rows in test_dataloader

    Args:
    - model (VQAModel): the model object
    - test_dataloader (Dataloader)
    - device (torch.device)

    Returns:
    - results (json): all inferences in json format for VizWiz
    """
    results = []
    for _, batch in tqdm(enumerate(test_dataloader), total=len(test_dataloader)):
        image_features, question_features, img = batch
        image_features = image_features.to(device)
        question_features = question_features.to(device)
        img = img[0]
        output = model.predict(image_features, question_features)
        predicted_answer = torch.argmax(output)
        answer = ANSWER_CATEGORIES[predicted_answer.item()]
        results.append({
            "image": img,
            "answer": answer
        })

    with open('submission.json', 'w') as f:
        json.dump(results, f)

# %%
get_all_test_inference(model, test_dataloader, DEVICE)
# Out:
#   0%|          | 0/8000 [00:00<?, ?it/s]

# %%
with open('submission.json', 'r') as f:
    data = json.load(f)

# %%
print(len(data))
# Out:
# 8000

# %%
idx = 10
img = data[idx]['image']
print(img)
answer = data[idx]['answer']

question = test_df[test_df['image'] == img].question
img = Image.open(TEST_PATH + '/' + img)
plt.imshow(img)

print(question, "Ans: ", answer)
# Out:
# VizWiz_test_00000010.jpg
# 10    Whats the date?
# Name: question, dtype: object Ans:  unanswerable

# %% [markdown]
# ### Inference for the AP Model

# %%
# epoch = ap_best_params['num_epochs']
epoch = 50
# ap_model = APModel(device= DEVICE, dropout_rate=ap_best_params['dropout_rate'], hidden_size=ap_best_params['fc_layer_size']).to(DEVICE)
ap_model = APModel(device=DEVICE).to(DEVICE)
ap_model.load_model(OUTPUT_PATH + "ap_epoch_{}.pth".format(epoch))
# Out:
# APModel(
#   (answerability_loss_fn): BCELoss()
#   (linear_layer1): Sequential(
#     (0): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#     (1): Dropout(p=0.5, inplace=False)
#     (2): Linear(in_features=2048, out_features=512, bias=True)
#   )
#   (linear_layer2): Sequential(
#     (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=512, out_features=1, bias=True)
#   )
#   (answerability_sigmoid): Sigmoid()
# )

# %%
def get_all_test_inference_ap(model, test_dataloader, device):
    """
    Obtains AP inferences for all rows in test_dataloader

    Args:
    - model (APModel): the model object
    - test_dataloader (Dataloader)
    - device (torch.device)

    Returns:
    - results (json): all inferences in json format for VizWiz
    """
    results = []
    for _, batch in tqdm(enumerate(test_dataloader), total=len(test_dataloader)):
        image_features, question_features, img = batch
        image_features = image_features.to(device)
        question_features = question_features.to(device)
        img = img[0]
        output = model.predict(image_features, question_features)
        results.append({
            "image": img,
            "answerable": output.item()
        })

    with open('ap_submission.json', 'w') as f:
        json.dump(results, f)

# %%
get_all_test_inference_ap(ap_model, test_dataloader, DEVICE)
# Out:
#   0%|          | 0/8000 [00:00<?, ?it/s]

# %%
with open('ap_submission.json', 'r') as f:
    ap_data = json.load(f)

# %%
print(len(ap_data))
# Out:
# 8000

# %%
idx = 10
img = ap_data[idx]['image']
print(img)
answer = ap_data[idx]['answerable']

question = test_df[test_df['image'] == img].question
img = Image.open(TEST_PATH + '/' + img)
plt.imshow(img)

print(question, "Ans: ", answer)
# Out:
# VizWiz_test_00000010.jpg
# 10    Whats the date?
# Name: question, dtype: object Ans:  0.0071279555559158325
